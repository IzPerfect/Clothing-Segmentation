# %%
from keras.models import load_model
import matplotlib.pyplot as plt
import cv2
import numpy as np

import os
from data_utils import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load model

# %%
fcn = load_model('./save_model/FCN_model.h5')
deeplab = load_model('./save_model/DeepLabV2_model.h5')
unet = load_model('./save_model/UNet_model.h5')

# %% [markdown]
# # Load Images

# %%
IMG_HEIGHT = 384
IMG_WIDTH = 256

x_train = np.load('dataset/x_train.npy').astype(np.float32)
x_test = np.load('dataset/x_test.npy').astype(np.float32)
y_train = np.load('dataset/y_train_onehot.npy').astype(np.float32)
y_test = np.load('dataset/y_test_onehot.npy').astype(np.float32)

x_train /= 255.
x_test /= 255.
y_train /= 255.
y_test /= 255.

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (900, 384, 256, 3) (900, 384, 256, 4)
# (100, 384, 256, 3) (100, 384, 256, 4)

# %%
# refer to https://github.com/mzaradzki/neuralnets/blob/master/vgg_segmentation_keras/fcn16s_segmentation_keras2.ipynb

# %%
image_num = 2

# %%
save_file = True
save_file_name1 = 'show result FCN.png'
save_file_name2 = 'show result DeepLab.png'
save_file_name3 = 'show result U-Net.png'

# %%
show_result(fcn, x_test[image_num], y_test[image_num], title = 'FCN', save_file = save_file, save_file_name = save_file_name1)

# %%
show_result(deeplab, x_test[image_num], y_test[image_num], title = 'DeepLab V2', save_file = save_file, save_file_name = save_file_name2)

# %%
show_result(unet, x_test[image_num], y_test[image_num], title = 'U-Net', save_file = save_file, save_file_name = save_file_name3)

# %%
iamge_segmentation(unet, x_test[image_num], save_file = True, save_file_name = 'segmentation')
